# %%
import pandas as pd

specie = 'aurita'

path = f'../data/csv_prepared/{specie}_location_fixed_prepared_mapped.csv'

df = pd.read_csv(path)
df
# Out:
#     observed_on   latitude  longitude place_state_name  \
# 0    10/04/2005 -22.415519 -43.398463   Rio de Janeiro
# 1    01/05/2006 -21.925034 -42.871454     Minas Gerais
# 2    23/10/2009 -22.273861 -47.564140        São Paulo
# 3    21/05/2011 -21.868276 -42.896158     Minas Gerais
# 4    01/07/2011 -23.159688 -44.820074        São Paulo
# ..          ...        ...        ...              ...
# 251  22/04/2025 -23.639248 -45.961316        São Paulo
# 252  09/05/2025 -22.085907 -45.199460     Minas Gerais
# 253  18/05/2025 -22.581037 -43.139387   Rio de Janeiro
# 254  20/05/2025 -23.364807 -46.877321        São Paulo
# 255  22/05/2025 -23.534093 -45.939392        São Paulo
#
#                                                    url  \
# 0    https://www.inaturalist.org/observations/18312...
# 1    https://www.inaturalist.org/observations/12180677
# 2    https://www.inaturalist.org/observations/37692783
# 3    https://www.inaturalist.org/observations/26091...
# ...

# %%
counting_df = df['image_url'].value_counts().reset_index()

counting_df.query("count > 1")
# Out:
# Empty DataFrame
# Columns: [image_url, count]
# Index: []
